# %% [raw]
# Q1. Explain the key features of python that make it a popular choice for programming.
#
#
# Ans: Python is beginner friendly and has a readable syntax. It has a
# vast library that save developers precious time. It has a strong community and
# an object-oriented approach for programming which saves time and makes programming easier.
#
# Q2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# Ans: Predefined keywords in Python are reserved for their specific function and cannot be used as identifiers.
# These keywords define the code and are the building blocks of a program written in Python.
# For example: the 'print' keyword outputs string on the screen, 'for','while' keywords are used for looping.
#
# Q3. Compare and contrast mutable and immutable objects in Python with examples.
#
# Ans: Mutable objects can be altered while immutable objects cannot be altered or
# changed once declared. For example, a character in a string cannot be assigned to another
# character, similarly an element of a set cannot be changed to another.In case of mutable objects like
# a list, the elements can be changed after declaration.
#
# Q4. Discuss the different types of operators in Python and provide examples of how they are used.
#
# Ans: The following are the types of operators in Python and their usage:
#
# 1. Arithmetic Operators:
# The operators that perform basic mathematical operations.
# For Example:
#            + (Addition): 5 + 3 equals 8.
#            - (Subtraction): 4 - 1 equals 3.
#            * (Multiplication): 2 * 3 equals 6.
#            / (Division): 4 / 2 equals 2.
#            // (Floor Division): 10 // 3 equals 3.
#            % (Modulo): 5 % 2 equals 1.
#            ** (Power): 4 ** 2 equals 16.
#
# 2. Assignment Operators:
# The operators that assign values to variables.
# For Example:
#            = (Assignment): y = 5 assigns 5 to y.
#            += (Addition Assignment): a += 1 is same as a = a + 1.
#            -= (Subtraction Assignment): a -= 3 is same as a = a - 3.
#            *= (Multiplication Assignment): a *= 4 is same as a = a * 4.
#            /= (Division Assignment): a /= 3 is same as a = a / 3.
#
# 3. Comparison Operators:
# The operators that compare two values and return a boolean result (True or False).
# Examples:
#            == (Equal To): 3 == 5 returns False.
#            != (Not Equal To): 3 != 5 returns True.
#            > (Greater Than): 3 > 5 returns False.
#            < (Less Than): 3 < 5 returns True.
#            >= (Greater Than or Equal To): 3 >= 5 returns False.
#            <= (Less Than or Equal To): 3 <= 5 returns True.
#
# 4. Logical Operators:
# The operators that combine boolean values.
# Examples:
# and: True and False results in False.
# or: True or False results in True.
# not: not True results in False.
#
# 5. Bitwise Operators:
# The operators that perform bit-level operations.
# Examples:
# & (Bitwise AND): 5 & 3 returns 1.
# | (Bitwise OR): 5 | 3 returns 7.
# ^ (Bitwise XOR): 5 ^ 3 returns 6.
# ~ (Bitwise NOT): ~ 10 returns -11.
# <<(Left Shift): Adds zeros at the end of the binary equivalent of the number operated on.
# >>(Right Shift): Removes binary numbers from the end of the binary equivalent of the
# number operated on.
#
# 6. Identity Operators:
#
# is and is not: These are used for identity comparison.
#
# 7. Membership Operators:
#
# in and not in: These are used to check if a value exists in objects like list or string.
#
# Q5. Explain the concept of type casting in Python with examples.
#
# Ans: There are two types of casts namely , implicit and explicit. Implicit cast
# is done by Python itself when a float and an int type data is added wherein int is
# promoted to float. Explicit cast on the other hand is performed by the programmer,
# when one converts a numerical string, for example '10000' to an int type using int('10000') command.
#
#
# Q6 How do conditional statements work in Python? Illustrate with examples.
#
# Ans: Conditional statements in Python are used to execute different code blocks based on certain conditions.
# The most common conditional statements in Python are if, elif (abbreviation for "else if"), and else.
#
# 1. if statement:
#
# if condition:
#     # code block to be executed if the condition is True
#
# For example:
#
# isAlive = true
#
# if isAlive:
#     print('can eat')
#     print('can write code')
#     print('can sleep')
#
# In the above code, as isAlive is true the code block is executed and the text is
# printed on the screen.
#
# 2. if-else statement:
#
# if condition:
#     # code block to be executed if the condition is True
# else:
#     # code block to be executed if the condition is False
#
#
# For example:
#
# Score = 89
#
# if Score > 90:
#     print('Excellent Score :)')
#
# else:
#     print('Better luck next time :(')
#
# In the above code, as Score is less than 90 the else block is executed and the corresponding
# text is printed.
#
# 3. if-elif-else statement:
#
# if condition1:
#     # code block to be executed if condition1 is True
# elif condition2:
#     # code block to be executed if condition2 is True
# else:
#     # code block to be executed if all conditions are False
#
#
# x = 0
# if x > 0:
#     print("x is positive")
# elif x < 0:
#     print("x is negative")
# else:
#     print("x is zero")
#
# In the above code, as x is 0 the else block is executed and the corresponding
# text is printed.
#
#
# Q7. Describe the different types of loops in Python and their use cases with examples.
#
# Ans: In Python, there are several types of loops that are commonly used to iterate over sequences or execute a block of code repeatedly.
# The main types of loops in Python are for loop, while loop, and nested loops.
#
# 1. for loop:
#
# The for loop is used to iterate over a sequence such as a list, tuple, string, or range.
#
# colors = ["red", "green", "blue"]
# for color in colors:
#     print(color)
#
# 2. while loop:
# The while loop is used to execute a block of code as long as a specific condition is true.
#
# count = 10
# while count > 0:
#     print(count)
#     count -= 1
#
# Prints 10,9,8,7,6....1 on the screen on discrete lines.
#
# 3.Nested loops:
#
# Nested loops are loops within loops.
# They are used to iterate over multiple sequences or to perform repeated operations.
#
# For example:
# Printing a square on the screen:
#
# for i in range(4):
#     for j in range(4):
#         print('*')
#     print( )
#
# In this case, it is a 3 x 3 square.
#
# 4. Break and continue statements:
#
# 1. break keyword is used to break out of a loop.
# 2. continue keyword is used to skip the current iteration and start from
#    the beginning of the loop.
