# %%
# Object Oriented Programming Systems

# %%
a = 5
b = "yo yo"

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# classes are blueprints/templates for creating an object 
# Note: Objects are basically variables made from the class.

# %%
class Laptop:  # UpperCamelCase
    pass

# %%
print(type(Acer_Aspire_7))
# Out:
# <class '__main__.Laptop'>

# %%
# A project can have many components , say backend(f1,f2), frontend(f3,f4), data pipeline(f5,f6)

# %%
def f1():
    pass

def f2():
    pass
# ........till f6()

# All the functions are in one place, unarranged
# OOPS helps us arrange the reuired functions in respective classes

# %%
class Laptop:
   
    def Power_ON(self):
        print("Laptop is powering on.")

    def Power_OFF(self):
        print("Laptop is shutting down.")

    # self >>  a variable that represents instance of the class using which you 
    # can access method
    # or function of class, also attribute/property
    # in other words the method is refrenced to that particular object
    # self is not a keyword and you can write anything in place of it
    # best practice is to pass 'self'

# %%
Acer_Aspire_7 = Laptop()
Acer_Aspire_7.Power_ON()
Acer_Aspire_7.Power_OFF()
# Out:
# Laptop is powering on.
# Laptop is shutting down.

# %%
class Laptop:
    def __init__(self,Name,CPU,GPU,RAM):
       self.Name = Name
       self.CPU = CPU
       self.GPU = GPU
       self.RAM = RAM
    
    def Power_ON(self):
        print("Laptop is powering ON.")

    def Display_Sys_Config(self):
        print("Device name : " + self.Name)
        print("CPU : " + self.CPU)
        print("Graphics : " + self.GPU)
        print("Total RAM : " + str(self.RAM) + " GB")

# %%
MyLaptop = Laptop("Acer Aspire 7","Ryzen 5 5500U","GTX 1650",16)
MyLaptop.Display_Sys_Config()
# Out:
# Device name : Acer Aspire 7
# CPU : Ryzen 5 5500U
# Graphics : GTX 1650
# Total RAM : 16 GB

# %%
class Bank:
    Net_Balance = 100000
    
    def deposit(self,amount):
        self.Net_Balance += amount
        print("Deposited " + str(amount))

    def balance(self):
        print("Balance : " + str(self.Net_Balance))
        
    def withdraw(self,amount_withdraw):
        self.Net_Balance -= amount_withdraw
        print("Withdrew " + str(amount_withdraw))

# %%
User1 = Bank()
User1.balance()
User1.withdraw(10000)
User1.balance()
User1.deposit(10000000)
User1.balance()
# Out:
# Balance : 100000
# Withdrew 10000
# Balance : 90000
# Deposited 10000000
# Balance : 10090000

# %%
class ListOps:
    l = [1,2,3,4,5,6]
    def extract_even(self,l):
        l1  = []
        for i in l:
            if i%2 == 0 :
                l1.append(i)
        return l1
    def extract_odd(self,l):
        l2  = []
        for i in l:
            if i%2 != 0 :
                l2.append(i)
        return l2

# %%
My_list_ob = ListOps()
print(My_list_ob.extract_even(My_list_ob.l))
print(My_list_ob.extract_odd(My_list_ob.l))
# Out:
# [2, 4, 6]
# [1, 3, 5]

# %%
class ListOps:
    
    def __init__(self,l):  # dunder method --- Double underscores
        self.l = l # accesible everywhere using self
        
    def extract_even(self): # be careful as init has been used only pass self in the method
        l = self.l
        l1  = []
        for i in l:
            if i%2 == 0 :
                l1.append(i)
        return l1
    def extract_odd(self):
        l = self.l
        l2  = []
        for i in l:
            if i%2 != 0 :
                l2.append(i)
        return l2

# %%
list9 = ListOps([1,3,4,5,6,77,88,432,222,45,5,67,44])

# %%
list9.extract_even()
# Out:
# [4, 6, 88, 432, 222, 44]

# %%
list9.extract_odd()
# Out:
# [1, 3, 5, 77, 45, 5, 67]

# %%
# Inheritance ----> refers to process of child receiving the properties of parent class

# %%
# class BaseClass:
#     #body of BaseClass
# class DerivedClass(BaseClass):
#     #body of DerivedClass

# %%
# single inheritance >> when a derived class has only one parent class

# %%
# example: - 
class Father:
    def father_prop(self):
        print("A $250000 House")

class Son(Father):
    def work(self):
        print("I go to college.")

# %%
Cal = Father()
Nate = Son()
Nate.work()
Nate.father_prop()
# Out:
# I go to college.
# A $250000 House

# %%
# Parent object cannot acces the properties of child class
# But child object can access both

# %%
# method overriding>> re-writing / redefining methods of parent class
class Fruit:
    def fruit_info(self):
        print("Inside Parent class")

class Apple(Fruit):
    def fruit_info(self):
        print("HA HA HA I RULE")
    def apple_info(self):
        print("Inside the child class")

# %%
AppleObj = Apple()
AppleObj.fruit_info()
FruitObj = Fruit()
FruitObj.fruit_info()
# Out:
# HA HA HA I RULE
# Inside Parent class

# %%
# multi-level inheritance
# Parent Class -> Child Class 1 -> Child Class 2

class Grandfather:
    def prop_grandfather(self):
        print("I am your grandfather, this is my property")

class Father(Grandfather):
    def prop_father(self):
        print("I am your father. I have my grandfather's property and mine.")

class Son(Father):
    def prop_son(self):
        print("I am the one...don't need a gun to get respect up on the street")

# %%
son = Son()
son.prop_father()
son.prop_grandfather()
son.prop_son()
# Out:
# I am your father. I have my grandfather's property and mine.
# I am your grandfather, this is my property
# I am the one...don't need a gun to get respect up on the street

# %%
father = Father()
father.prop_father()
father.prop_grandfather()
# Out:
# I am your father. I have my grandfather's property and mine.
# I am your grandfather, this is my property

# %%
grandpop = Grandfather()
grandpop.prop_grandfather()
# Out:
# I am your grandfather, this is my property

# %%
# multiple inheritance

# %%
class Mom:
    def method_M(self):
        print("Mom")

class Dad:
    def method_D(self):
        print("Dad")

class Child(Mom,Dad):   # Multiple Inheritance
    def method(self):
        print("guuguugagga")

# %%
c1 = Child()
c1.method_D()
c1.method_M()
c1.method()
# Out:
# Dad
# Mom
# guuguugagga

# %%
# Diamond Problem ->> When a class inherits from 2 or more classes
# will lead to ambiguity as to which method will be executed
# To fix this: Python uses method resolution order (MRO) algorithm called c3
# linearization.
# The class that is inherited first will be the one who's method is executed.
class Mom:
    def method_p(self):
        print("Mom")

class Dad:
    def method_p(self):
        print("Dad")

class Child(Mom,Dad):   # Multiple Inheritance
    def method(self):
        print("guuguugagga")

# %%
c2 = Child()
c2.method_p()
c2.method()
# Out:
# Mom
# guuguugagga

# %%
# hierarchical inheritance -> one parent class , many child classes derived from it

# %%
class Vehicle:
    def can_drive(self):
        print("I drive")

class Car(Vehicle):
    pass

class Truck(Vehicle):
    pass

# %%
car = Car()
truck = Truck()
car.can_drive()
truck.can_drive()
# Out:
# I drive
# I drive

# %%
# Hybrid Inheritance --> multiple types or combination of different inheritance

# %%
class Vehicle:
    def vehicle_info(self):
        print("Inside Vehicle")

class Car(Vehicle):
    def car_info(self):
        print("Inside Car")

class Bike(Vehicle):
    def bike_info(self,name):
        print("Riding a ", name)

class SportsCar(Car,Vehicle):
    def sportsCar_inf(self):
        print("Inside a sports car")

class Batman_Car(Car,Vehicle):
    def BatVehicle(self):
        print("I am BATMAN!")

# %%
batv = Batman_Car()
batv.BatVehicle()
batv.vehicle_info()
batv.car_info()
# Out:
# I am BATMAN!
# Inside Vehicle
# Inside Car

# %%
# Abstraction >> concept of hiding complex implemenation
# hiding unneeded details and exposing the required
# abstract class can not be instantiated
# abstract class should always be subclasses
# abstract class may contain methods that are just declared and not implemented
# in abstract class itself, subclasses are responsible for implememting these
# abstract methods..

# %%
# Abstraction can be achieved using abstract class >> import abc

# %%
import abc
# parent class is usually abstract so that the child classes can define their own
#methods
# if in inherited class a method is not present from abstract class it will not 
# throw an error

# %%
class School:

    @abc.abstractmethod  # abstract method
    def student_details(self):
        pass
    @abc.abstractmethod
    def student_assignment(self):
        pass
    @abc.abstractmethod
    def student_marks(self):
        pass

# %%
class ClassXII(School):
    def student_details(self):
        return "Class XII student details"
    def student_marks(self):
        return "Student Marks"

# %%
class ClassX(School):
    def student_details(self):
        return "Class X student details"
    def student_marks(self):
        return "Student Marks"

# %%
class12 = ClassXII()

# %%
class12.student_assignment()

# %%
class12.student_details()
# Out:
# 'Class XII student details'

# %%
classX = ClassX()
classX.student_assignment()

# %%
# Polymorphism --> poly means many and morphism means forms/states
# refers to an object taking several forms depending on the methods/data

# %%
len("Max")
# Out:
# 3

# %%
len([2,3,4])
# Out:
# 3

# %%
len((1,3,4,5,5,6))
# Out:
# 6

# %%
def add(a,b):
    return a + b

# %%
add("Max"," Payne") # same function can concatenate strings and also add numbers
# Out:
# 'Max Payne'

# %%
add(2,3)
# Out:
# 5

# %%
add([1,2],[1,2,4,5,5])
# Out:
# [1, 2, 1, 2, 4, 5, 5]

# %%
# add takes different forms with respect to data passed

# %%
class teacher_lec:
    def lec_info(self):
        print("This is lec info with teacher perspective")

class student_lec:
    def lec_info(self):
        print("This is lec info with student perspective")

# %%
obj1 = teacher_lec()
obj2 = student_lec()
class_obj = [obj1,obj2]

# %%
def passer(class_obj):
    for i in class_obj:
        i.lec_info()   # lec_info is taking two forms >> bimorphic behaviour

# %%
passer(class_obj)
# Out:
# This is lec info with teacher perspective
# This is lec info with student perspective

# %%
# Method Overloading >> python doesnt support true method overloading

# %%
class Student:
    def student(self):
        print("I am a student.")
    def student(self,name = " "):
        print(" I am " ,name)
    def student(self, name = " ", course = " "):
        print(" I am ",name,course)
# Most recent method will be executed...

# %%
stud = Student()

# %%
stud.student(13)
# Out:
#  I am  13

# %%
stud.student("Max",13)
# Out:
#  I am  Max 13

# %%
# Method overloading >> student method is taking different forms , the last 
# method overloads the previous ones
#Method overloading happens in the same class

# %%
#Method overriding >> method in parent class is implememnted in child class

# %%
# Encapsulation: means hiding something
# bundling of data and methods of a class
# access modifiers(public,protected,private)

# %%
class Student:
    def __init__(self,name,degree):
        self.name = name
        self.degree = degree

# %%
S1 = Student("Max","Bachelor in CSE")
print(S1.name)
print(S1.degree)
# Out:
# Max
# Bachelor in CSE

# %%
S1.name = "Maxine"
print(S1.name)
# Out:
# Maxine

# %%
class Student:
    def __init__(self,name,degree):
        self.name = name
        self.degree = degree
    def show(self):
        #accessing private anf public data member
        print("Name: ",self.name)
        print("Degree: ",self.degree)

Max = Student("Max","BTech in CSE")

# %%
Max.show()
print(Max.degree)
print(Max.name)
# Out:
# Name:  Max
# Degree:  BTech in CSE
# BTech in CSE
# Max

# %%
# private: data and methos is only accessible within class
# add two underscores before variable name to hide it (like degree in the class
# below)

# %%
class Student:
    def __init__(self,name,degree):
        self.name = name
        self.__degree = degree # __ is added tpo make it private
    def show(self):
        #accessing private anf public data member
        print("Name: ",self.name)
        print("Degree: ",self.__degree)

Max = Student("Max","BTech in CSE")

# %%
Max.show()
# Out:
# Name:  Max
# Degree:  BTech in CSE

# %%
Max.degree
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 Max.degree
#
# AttributeError: 'Student' object has no attribute 'degree'

# %%
Max.name
# Out:
# 'Max'

# %%
Max._Student__degree # To access degree if you really , really want to
# Syntax to access private memebers:
# ObjectName._(one underscore)ClassName__(Two-underscores)PvtVariableName
# Out:
# 'BTech in CSE'

# %%
# TO MAKE A METHOD PRIVATE

# %%
class Student:
    def __init__(self,name,degree):
        self.name = name
        self.__degree = degree # __ is added tpo make it private
    def __private_access_only(self):  # made it pvt with __ two underscores
        #accessing private anf public data member
        print("Name: ",self.name)
        print("Degree: ",self.__degree)

    def Access_Private_Method(self):
        Passkey = "2005"
        EnteredPass = str(input("Enter Pass: "))

        if EnteredPass == Passkey:
                self.__private_access_only()
                
        else:
            print("Invalid Pass..Try again")

        if EnteredPass != Passkey:
            self.Access_Private_Method()
            
            
        


S1 = Student("Max","BTech in CSE")

# %%
S1._Student__private_access_only()  # Accessing private methods
# Out:
# Name:  Max
# Degree:  BTech in CSE

# %%
S1.Access_Private_Method()
# Out:
# Enter Pass:  2135
# Invalid Pass..Try again
# Enter Pass:  2005
# Name:  Max
# Degree:  BTech in CSE

# %%
# Using getters and setters
class Car:
    def __init__(self,year,make,speed,model):
        self.__year = year
        self.__make = make
        self.__speed = speed
        self.__model = model
    def set_speed(self,speed):
        self.__speed = 0 if speed < 0 else speed
    def get_speed(self):
        return self.__speed

# %%
c1 = Car(2015,"Mustang",180,"Ford")
c1.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[284], line 2
#       1 c1 = Car(2015,"Mustang",180,"Ford")
# ----> 2 c1.year
#
# AttributeError: 'Car' object has no attribute 'year'

# %%
c1.get_speed()
# Out:
# 180

# %%
c1.set_speed(200)
c1.get_speed()
# Out:
# 200

# %%
# protected: within the class and its subclass, protected member can be access,(_)

# %%
class College:
    def __init__(self):
        self._college_name = "Stanford"

class Student(College):
    def __init__(self,name):
        self.name = name
        College.__init__(self) # accessing variable of base class

    def show(self):
        print("name",self.name,"college",self._college_name) # directly call the base 
                                                   # class variable one underscore

# %%
stud = Student("Max")

# %%
stud.show() # This should work
# Out:
# name Max college Stanford

# %%
# Another way to access the data of base class using super()
class College:
    def __init__(self):
        self._college_name = "Stanford"

class Student(College):
    def __init__(self,name):
        self.name = name
        super().__init__() # 

    def show(self):
        print("Name : ",self.name," , College : ",self._college_name) # directly call the base 
                                                   # class variable one underscore

# %%
stud = Student("Max")

# %%
stud.show()
# Out:
# Name :  Max  , College :  Stanford

# %%
# class methods >> bound to the class (and not to an object)
# instead of self, cls as first parameter

# %%
class Student:
    # constructor >> constructing class with initialization of variables or data
    def __init__(self,name):
        self.name = name # self means referring to current instance of the class

    @classmethod #bound to the class
    def student_details(cls,name): # instead of self as first param, we use cls
        return cls(name)           # meaning this method is referring to the class
                                   # itself.

# %%
R_no_1 = Student("Max")

# %%
R_no_1.name
# Out:
# 'Max'

# %%
# Earlier to acces any method or attrib , we made instances of the class then used
# dot operator
# class method decorator
# but if it is class method we can access it directly
# alternative of init method to pass the data

# %%
obj = Student.student_details("Max") # since student_details is bound to the class
# directly , it can be called directly

# %%
obj.name
# Out:
# 'Max'

# %%
# class method as alternative of init method >> class method is actually overloading 
# init method

# %%
# How is class method overloading init?
# modifying the instance method
class Student:
    def __init__(self,name): #  init method is an instance method
        self.name = name 

    @classmethod #bound to the class
    def student_details(cls,name1): 
        return cls(name1)

# %%
stud = Student.student_details("Maxine")

# %%
stud.name
# Out:
# 'Maxine'

# %%
# class method can modify class state applicable to all the instances of the class

# %%
class Student:
    total_students = 0
    def __init__(self,name):
        self.name = name  # instance variable
        Student.total_students += 1 # total_student is the class variable
                                   # notice how we used Student instead of self
    @classmethod
    def get_total_students(cls):
        return cls.total_students

# %%
Student.total_students
# Out:
# 0

# %%
std1 = Student("Max")
std2 = Student("Maxine")

# %%
std1.name
# Out:
# 'Max'

# %%
std2.name
# Out:
# 'Maxine'

# %%
Student.total_students
# Out:
# 2

# %%
Student.get_total_students() # class method can modify class state applicable to all
# the instances thats why we see an increase in the count
# Out:
# 2

# %%
class Student:
    total_students = 0
    def __init__(self,name):
        self.name = name  # instance variable
        Student.total_students += 1 # total_student is the class variable
                                   # notice how we used Student instead of self
    @classmethod
    def get_total_students(cls):
        return cls.total_students

# %%
def course_details(cls,course_name):
    print("The details of the course are: " , course_name)

# %%
Student.course_details = classmethod(course_details)
#classmethod(your external function goes here) ---> it converts an external function
# to a class function

# %%
Student.course_details("Data Science with AI")
# Out:
# The details of the course are:  Data Science with AI

# %%
#delete any class method
del Student.course_details

# %%
Student.course_details("Data Science") # it throws error as the method referred to here
# has been deleted
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 Student.course_details("Data Science") # it throws error as the method referred to here
#       2 # has been deleted
#
# AttributeError: type object 'Student' has no attribute 'course_details'

# %%
Student.get_total_students()
# Out:
# 0

# %%
delattr(Student,"get_total_students")
# deletes the named attrib from the given object

# %%
Student.get_total_students()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 Student.get_total_students()
#
# AttributeError: type object 'Student' has no attribute 'get_total_students'

# %%
# Static method
# Does not modify class or instance state
# Does not depend upon class/instance
# it behaves like a normal function that belongs to the class
# it doesnt tame either self or cls
# @staticmethod is used
# works with the parameters passed

# %%
class Calculator:

    @staticmethod
    def add(x,y):
        return x + y

    @staticmethod
    def sub(x,y):
        return x - y

# %%
Calculator.add(1,99)
# Out:
# 100

# %%
Calculator.sub(10001,1)
# Out:
# 10000

# %%
# Dunder method/Magic/special method
# are methods defined by built-in classes in Python
# classes define these type of methods for creating custom methods 
# helps implement overloading

# %%
# dunder --> double underscores >> methods surrounding double underscores(__)

# %%
a = "Max "
b = "Payne"
a + b
# Out:
# 'Max Payne'

# %%
a.__add__(b)  # Revelation: + in python is equivalent to __add__
# Out:
# 'Max Payne'

# %%
# all dunder methods associated with string
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
n1 = 1
n2 = 5
n1.__add__(n2)
# Out:
# 6

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
 # another magic method --> __new__

# %%
class Student:
    # responsible for creating a new instance of the class
    def __new__(cls): # cls is passed --> referring to this class
        print("This will be executed even before init")

    # used to initialize newly created instance/object
    def __init__(self,name):
        print(name,"This is the first thing that will be executed when you make an instance.")

# %%
obj = Student()
# Out:
# This will be executed even before init

# %%
# another dunder method --> __str__

# %%
class Student:
    def __init__(self):
        self.phone = 983460010
    def __str__(self):
        return "Overloads print statement of object method"

# %%
Student() # Hexadecimal representation of memory of Student object

# %%
print(Student()) # overloading default Hexadec representation
# Out:
# Overloads print statement of object method

# %%
# __rep__ method >> meaning representation
# it returns unambiguous string rep of the obj as it is that can be used to recreate the 
#object

# %%
class AnyClass:
    def __init__(self,x):
        self.x = x
    def __repr__(self):
        return f"AnyClass({self.x})"

# %%
obj = AnyClass(5)

# %%
print(repr(obj))
# Out:
# AnyClass(5)

# %%
# __eq__  
# (__eq__) = (==)
True == False
# Out:
# False

# %%
a = 234
b = 234
a.__eq__(b)
# Out:
# True

# %%
class Coordinate:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __eq__(self,other): # we redefined it for this class
        return self.x == other.x and self.y == other.y

# %%
p1 = Coordinate(1,2)
p2 = Coordinate(3,4)
print(p1 == p2)
# Out:
# False

# %%
class Coordinate:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __add__(self,other): # we redefined it for this class
        return Coordinate(self.x + other.x ,self.y + other.y)

# %%
p1 = Coordinate(1,2)
p2 = Coordinate(3,4)
p3 = p1 + p2 
print(p3.x,p3.y)
# Out:
# 4 6

# %%
# Decorators -> allows to modify or extend the behaviour of funtions/classes without directly 
# modifying their code
# Similar to decorating your room ( Putting lights and TV , Extends the behaviour)

# %%
# function decorators and class decorators 
# function decorators

# %%
# Example: say we wanna use line before and after computation each time we create a function 
# or call it
# It will take a lot of time to tyoe these lines repeatedly
# This is why the concept of decorators comes into picture
def my_decorator_func():
    print("line before computing")
    print(11*1000)
    print("line after computing")
# The above approach is redundant 
my_decorator_func()
# Out:
# line before computing
# 11000
# line after computing

# %%
# Decorator approach for functions
def my_decorator(func): # decorator funciton that takes another funciton as argument
    def wrapper(): # Wrapper i snested funciton that adds the funcitonality beffor e nad after calling func
        print("line before computing")
        func()
        print("line after computing")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello")

# %%
say_hello()
# WHen say hello is called it actually calls the decorator function first , 
# which in return calls the wrapper function which prints the lines and then 
# finally the say HEllo fucnition is also called
# Out:
# line before computing
# Hello
# line after computing

# %%
# Another Usage
# Runtime of a code

import time 
def timer_decorator(func):
    
    def timer():
        start = time.time()
        func()
        end = time.time()
        print("The time it took for execution is ", end - start, " seconds")
    
    return timer

# %%
@timer_decorator
def func_test():
    for i in range(100000):
        print(":)",end = " ")
        print("")
        i += 1

# %%
func_test()
# Out:
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# :)
# ...

# %%
# WHy do we need decorators?
# Reusability of code
# Enhacing the function without modifying the original function
# use cases >> execution time of code, logging,caching,validation

# %%
# Class Decorators
class MyDecorator:
    def __init__(self,func): # similar to func decorator we pass func parameter
        self.func = func
        print("I live inside Init method")
    def __call__(self): 
        print("Happens before function is called")
        self.func()
        print("Happens after function has been called")

# %%
@MyDecorator # class __call__ will be executed as the object  if the class will be called as functions
def say_hello(): # first init will be executed and then call will be executed
    print("Hello")
say_hello()
# Out:
# I live inside Init method
# Happens before function is called
# Hello
# Happens after function has been called

# %% [raw]
# # call is a special method which is called or invoked when
#                         # we call instance/object of the class as a function

# %%
class MyDecorator:
    def __init__(self): # similar to func decorator we pass func parameter
        #self.func = func
        print("I live inside init method")
    def __call__(self): 
        print("Happens before function")
        # self.func()
        print("Happens after function")
     


obj = MyDecorator()
# Out:
# I live inside init method

# %%
obj() # when we call an object of a class as a function __call__ method will be invoked
# Out:
# Happens before function
# Happens after function

# %%
# Some inbuilt decorators 
# @classmethod >> the method that takes the class itself as first argument

# %%
class Math:
    @classmethod # takes refrence to class itself to modify and access class level attrib
    def add(cls, x, y): 
        return cls.__name__,x+y

# %%
Math.add(2,4)
# Out:
# ('Math', 6)

# %%
# class methods are bound to the class and not the instance of the class
# class itself as the first argument >> convemtionally cls

# %%
import math

# %%
math_obj = math() # We cannot create objects from math class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 math_obj = math() # We cannot create objects from math class
#
# TypeError: 'module' object is not callable

# %%
math.ceil(2.5) # This is a class method
# Out:
# 3

# %%
# Static method 
# This can be called without creating any instance of the class , and without 
# using self or cls

# %%
class MyMath:
    def add(self,x,y):
        return x + y

# %%
a = MyMath()
a.add(3,50)
# Out:
# 53

# %%
# Using Static Method
class MyMath:

    @staticmethod
    def add(x,y):
        return x + y

# %%
MyMath.add(2,55)
# Out:
# 57

# %%
# class method is used when we want to modify class level data
# static method >>  when we don't wanna interact with class level data

# %%
# Property decorator >> Allows method to be accessed as attribute/variable

# %%
# Without Decorator
class Circle:
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        radius = self.radius
        return 3.14*radius**2

# %%
obj = Circle(5)

# %%
obj.radius
obj.area()
# Out:
# 78.5

# %%
# Without Decorator
class Circle:
    def __init__(self,radius):
        self.radius = radius

    @property
    def area(self):
        radius = self.radius
        return 3.14*radius**2

# %%
obj1 = Circle(5)
obj1.area # no need of paranthesis for calling this function
# Out:
# 78.5

# %%
class Student:
    def __init__(self,name,grade):
        self.__name = name
        self.__grade = grade

# %%
# name and grade are private variables

# %%
stud = Student("Max",12)

# %%
stud._Student__name # using class name
# Out:
# 'Max'

# %%
# Another way to expose private variables using property decorators

class Student:
    def __init__(self,name,grade):
        self.__name = name
        self.__grade = grade
        
    @property   
    def access_grade(self):
        return self.__grade

# %%
stud = Student("Max",12)

# %%
stud.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 stud.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
stud.access_grade # without function paranthesis
# Out:
# 12

# %%
# to modify price

# %%
class Student:
    def __init__(self,name,grade):
        self.__name = name
        self.__grade = grade
        
    @property   
    def access_grade(self):
        return self.__grade

    @access_grade.setter
    def grade_set(self,grade_new):
        self.__grade = grade_new

# %%
stud = Student("Max",12)

# %%
stud.grade_set = 11

# %%
stud.access_grade # setter property
# Out:
# 11

# %%
class Student:
    def __init__(self,name,grade):
        self.__name = name
        self.__grade = grade
        
    @property   
    def access_grade(self):
        return self.__grade

    @access_grade.setter
    def grade_set(self,grade_new):
        self.__grade = grade_new
        
    @access_grade.deleter
    def access_grade(self):
        del self.__grade

# %%
stud = Student("Maxine",12)

# %%
stud.access_grade
# Out:
# 12

# %%
stud.grade_set = 11

# %%
stud.access_grade
# Out:
# 11

# %%
stud.access_grade
# Out:
# 11

# %%
del stud.access_grade

# %%
stud.access_grade
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 stud.access_grade
#
# Cell In[169], line 8, in Student.access_grade(self)
#       6 @property
#       7 def access_grade(self):
# ----> 8     return self.__grade
#
# AttributeError: 'Student' object has no attribute '_Student__grade'
